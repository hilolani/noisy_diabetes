# %%
# !git clone https://github.com/hilolani/noisy_diabetes.git
# %pwd
# %cd noisy_diabetes
# !pip install .
# Out:
# Cloning into 'noisy_diabetes'...
# remote: Enumerating objects: 92, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 92 (delta 36), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (92/92), 533.30 KiB | 5.39 MiB/s, done.
# Resolving deltas: 100% (36/36), done.
# /content/noisy_diabetes
# Processing /content/noisy_diabetes
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from noisy_diabetes==0.1) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from noisy_diabetes==0.1) (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from noisy_diabetes==0.1) (1.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->noisy_diabetes==0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->noisy_diabetes==0.1) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->noisy_diabetes==0.1) (2025.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->noisy_diabetes==0.1) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->noisy_diabetes==0.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->noisy_diabetes==0.1) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->noisy_diabetes==0.1) (1.17.0)
# Building wheels for collected packages: noisy_diabetes
#   Building wheel for noisy_diabetes (setup.py) ... done
#   Created wheel for noisy_diabetes: filename=noisy_diabetes-0.1-py3-none-any.whl size=266038 sha256=745ddacb5a3581377b6036b23700b618af6533bd5249dd641f8134d8eace22b4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3c398doa/wheels/c6/9c/4a/480c91a30d750cfc6bdadee6941b70aac52cbaba883ef97558
# Successfully built noisy_diabetes
# Installing collected packages: noisy_diabetes
# Successfully installed noisy_diabetes-0.1

# %%
from noisy_diabetes import *

# %%
noisy_diabetes = load_noisy_diabetes()
pds.DataFrame(noisy_diabetes.data, columns=("age", "sex", "bmi", "map", "tc", "ldl", "hdl", "tch", "ltg", "glu"))
# Out:
#           age       sex       bmi       map        tc       ldl       hdl  \
# 0   -0.107226  0.050680  0.073729  0.108586  0.033467 -0.115613 -0.036430
# 1    0.053797 -0.044642 -0.090275 -0.081516  0.081129  0.103402  0.130280
# 2    0.110727  0.050680  0.167225  0.106081 -0.105451 -0.094694  0.087756
# 3   -0.107226  0.050680 -0.058498 -0.056409 -0.085503  0.116698 -0.102307
# 4    0.000717 -0.044642 -0.013336  0.120537  0.059739  0.001825  0.005390
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.047968 -0.044642 -0.062424 -0.016583  0.012260 -0.115613 -0.011174
# 438  0.050841 -0.044642 -0.015549 -0.112399  0.153914  0.147773  0.071706
# 439  0.110727  0.050680  0.149370  0.042599 -0.094609 -0.102333  0.010200
# 440  0.110727  0.026777  0.059886 -0.112399  0.153914  0.140372 -0.073985
# 441 -0.012420  0.050680 -0.090275  0.001498  0.121986  0.001251  0.181179
#
#           tch       ltg       glu
# 0    0.043853 -0.008717 -0.115178
# 1   -0.013074 -0.126097 -0.041420
# 2   -0.052354 -0.102463 -0.137767
# 3    0.082742  0.099401  0.135612
# 4    0.014153 -0.044340 -0.059418
# ..        ...       ...       ...
# 437  0.057147  0.133597  0.132844
# 438  0.103977  0.133597  0.054089
# 439 -0.076395  0.081887  0.104606
# 440  0.039052  0.068419 -0.048736
# 441 -0.076395  0.094780  0.095793
#
# [442 rows x 10 columns]

# %%
total_noisy_diabetes = load_total_noisy_diabetes()

# %%
pds.DataFrame(total_noisy_diabetes.data, columns=("participants", "sessions", "age", "sex", "bmi", "map", "tc", "ldl", "hdl", "tch", "ltg", "glu"))
# Out:
#       participants  sessions       age       sex       bmi       map  \
# 0                0         0 -0.107226  0.050680  0.073729  0.108586
# 1                0         1 -0.107254  0.051164  0.073112  0.108686
# 2                0         2 -0.107879  0.051455  0.073902  0.108866
# 3                0         3 -0.107753  0.049759  0.073995  0.108848
# 4                0         4 -0.107363  0.050990  0.073846  0.109327
# ...            ...       ...       ...       ...       ...       ...
# 2647           441         1 -0.012037  0.051532 -0.090679  0.001281
# 2648           441         2 -0.012543  0.050103 -0.090297  0.002462
# 2649           441         3 -0.012821  0.050231 -0.089817  0.002347
# 2650           441         4 -0.013084  0.051335 -0.089856  0.001280
# 2651           441         5 -0.013301  0.049745 -0.090870  0.001433
#
#             tc       ldl       hdl       tch       ltg       glu
# 0     0.033467 -0.115613 -0.036430  0.043853 -0.008717 -0.115178
# 1     0.033907 -0.115258 -0.036340  0.044152 -0.009285 -0.114733
# 2     0.033473 -0.116342 -0.036398  0.043215 -0.008695 -0.115840
# 3     0.033446 -0.115316 -0.035820  0.043690 -0.009423 -0.115210
# 4     0.032722 -0.115243 -0.036483  0.043051 -0.009518 -0.114587
# ...        ...       ...       ...       ...       ...       ...
# 2647  0.122911  0.001370  0.182082 -0.075786  0.094903  0.096780
# 2648  0.121620  0.000514  0.180313 -0.076701  0.094544  0.096711
# 2649  0.122144  0.001999  0.180549 -0.076293  0.094155  0.096137
# 2650  0.121424  0.001841  0.181477 -0.076037  0.095077  0.095085
# 2651  0.122245  0.001220  0.181834 -0.076793  0.094371  0.096190
#
# [2652 rows x 12 columns]

# %%
pds.DataFrame(total_noisy_diabetes.target, columns=(["index"]))
# Out:
#       index
# 0     151.0
# 1     149.0
# 2     151.0
# 3     153.0
# 4     149.0
# ...     ...
# 2647   59.0
# 2648   55.0
# 2649   56.0
# 2650   58.0
# 2651   55.0
#
# [2652 rows x 1 columns]
